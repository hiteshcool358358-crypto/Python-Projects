# %% [markdown]
# # Scipy

# %% [markdown]
# ### Scipy constants
# - These constants stores fixed values which are mostly used in scientific implementation

# %%
from scipy import constants as c

#this prints the value of pi
print(c.pi)

#dir() prints all the constants
print(dir(c))
